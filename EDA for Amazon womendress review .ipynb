# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('DressesReview.csv')
df.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
df.columns
# Out:
# Index(['s.no', 'age', 'division_name', 'department_name', 'class_name',
#        'clothing_id', 'title', 'review_text', 'alike_feedback_count', 'rating',
#        'recommend_index '],
#       dtype='object')

# %%
df.shape
# Out:
# (23486, 11)

# %%
## List out unique clothes

# %%
clothes=df['class_name'].unique()

clothes
# Out:
# array(['Jeans', 'Blouses', 'Skirts', 'Pants', 'Swim', 'Sweaters', 'Knits',
#        'Fine gauge', 'Jackets', 'Dresses', 'Shorts', 'Lounge',
#        'Outerwear', 'Intimates', 'Legwear', 'Sleep', 'Trend', 'Layering',
#        nan, 'Casual bottoms', 'Chemises'], dtype=object)

# %%
title=df['title'].unique()

# %%
## List out clothing id

# %%
df['clothing_id'].unique()
# Out:
# array([1028,  850,  993, ...,   32,  568,  222])

# %%
## List out unique division name

# %%
df['division_name'].unique()
# Out:
# array(['General', 'General Petite', 'Initmates', nan], dtype=object)

# %%
## List out the womens between the age of 30 to 40

# %%
df30to40 = df.loc[ (df['age'] >= 30) & (df['age'] <= 40) ]

df30to40.head()
# Out:
#     s.no  age division_name department_name class_name  clothing_id  \
# 0      0   40       General         Bottoms      Jeans         1028
# 4      4   37     Initmates        Intimate       Swim           24
# 7      7   34       General            Tops      Knits          868
# 10    10   32       General            Tops      Knits          872
# 15    15   31       General         Dresses    Dresses         1086
#
#                      title                                        review_text  \
# 0     Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 4   Great for bigger busts  I absolutely love the retro look of this swims...
# 7     Unique and wonderful  The sweater is comfortable and a good weight. ...
# 10               Great fit  I have been searching around for new and uniqu...
# 15       Not for my curves  5'7", 34c, 28 jeans, size 4 dress. fell in lov...
#
#     alike_feedback_count  rating  recommend_index
# ...

# %%
df30to40['review_text'].unique()
# Out:
# array(['Like other reviewers i was hesitant to spend this much on a pair of jeans. however, i purchased them at  20% off on retailer day and...honestly...they look so good i probably would have paid full price. these jeans are fresh!',
#        "I absolutely love the retro look of this swimsuit. i first saw it on blogger amber fillerup-clark (barefoot blonde) and i knew i had to have it. this is the first one piece suit i've purchased in about six years. i've avoided one pieces because most of the ones i tried made me feel frumpy, and the mono-kini look just looked odd on me. i have a smaller frame and a larger bust (32ddd), so finding swimsuits that fit properly is a challenge. i am a size 4 but i ordered a size 6 after reading reviews",
#        'The sweater is comfortable and a good weight. the zipper is very difficult, but i do not have to unzip the sweater to pull it on.',
#        ...,
# ...

# %%
df30to40['class_name'].unique()
# Out:
# array(['Jeans', 'Swim', 'Knits', 'Dresses', 'Blouses', 'Pants', 'Shorts',
#        'Jackets', 'Sweaters', 'Outerwear', 'Skirts', 'Lounge',
#        'Fine gauge', 'Trend', 'Legwear', 'Intimates', 'Sleep', nan,
#        'Layering', 'Chemises'], dtype=object)

# %%
### List out the womens between the age of 20 to 30

# %%
df20t030=df.loc[(df['age']>=20)&(df['age']<=30)]

df20t030
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 13        13   23         General         Bottoms     Skirts         1020
# 38        38   30  General Petite            Tops    Blouses          838
# 43        43   23       Initmates        Intimate       Swim          401
# 48        48   21  General Petite            Tops    Blouses          830
# 63        63   29         General            Tops    Blouses          833
# ...      ...  ...             ...             ...        ...          ...
# 23449  23449   26  General Petite         Dresses    Dresses         1110
# 23460  23460   23         General         Dresses    Dresses         1077
# 23475  23475   25  General Petite         Bottoms     Skirts         1008
# 23478  23478   26         General            Tops      Knits          883
# 23483  23483   29  General Petite            Tops      Knits          862
#
#                                       title  \
# ...

# %%
df['rating'].unique()
# Out:
# array([5, 1, 4, 2, 3])

# %%
## List out only top rating

# %%
dftoprating=df.loc[(df['rating']>=5)]

dftoprating
# Out:
#         s.no  age   division_name department_name class_name  clothing_id  \
# 0          0   40         General         Bottoms      Jeans         1028
# 1          1   62  General Petite            Tops    Blouses          850
# 3          3   45  General Petite         Bottoms      Pants         1068
# 4          4   37       Initmates        Intimate       Swim           24
# 6          6   83         General            Tops   Sweaters          937
# ...      ...  ...             ...             ...        ...          ...
# 23481  23481   44  General Petite         Dresses    Dresses         1081
# 23482  23482   39         General         Dresses    Dresses         1110
# 23483  23483   29  General Petite            Tops      Knits          862
# 23484  23484   57         General         Dresses    Dresses         1082
# 23485  23485   56         General         Jackets    Jackets          984
#
#                                        title  \
# ...

# %%
dftoprating['title']
# Out:
# 0                         Amazing fit and wash
# 1                           Lovely and unique!
# 3                                          Wow
# 4                       Great for bigger busts
# 6                        Beautiful and unique.
#                          ...
# 23481                                 Love it!
# 23482                              Great piece
# 23483                   So soft and flattering
# 23484    Another winner from isabella sinclair
# 23485                                      NaN
# Name: title, Length: 13131, dtype: object

# %%
dftoprating['class_name'].head()
# Out:
# 0       Jeans
# 1     Blouses
# 3       Pants
# 4        Swim
# 6    Sweaters
# Name: class_name, dtype: object

# %%
## Top rating cloth name

# %%
dftoprating['class_name'].unique()
# Out:
# array(['Jeans', 'Blouses', 'Pants', 'Swim', 'Sweaters', 'Knits',
#        'Fine gauge', 'Skirts', 'Jackets', 'Shorts', 'Dresses', 'Lounge',
#        'Intimates', 'Legwear', 'Outerwear', 'Sleep', nan, 'Layering',
#        'Trend', 'Casual bottoms'], dtype=object)

# %%
dftoprating['division_name'].unique()
# Out:
# array(['General', 'General Petite', 'Initmates', nan], dtype=object)

# %%
dftoprating['review_text']
# Out:
# 0        Like other reviewers i was hesitant to spend t...
# 1        As is true of a bunch of the fall clothing pho...
# 3        Love love this! i was hesitant to buy this at ...
# 4        I absolutely love the retro look of this swims...
# 6        Love this sweater!\r\nsoft and cozy and the ru...
#                                ...
# 23481    I oot this dress in the blue. it fits great--h...
# 23482    I was very patient with this dress. i was wait...
# 23483    The deep v doesn't gape, and flatters the neck...
# 23484    I saw this dress online this morning, went int...
# 23485    Super cute jacket .perfect for fall i can't st...
# Name: review_text, Length: 13131, dtype: object

# %%
dftoprating['department_name'].unique()
# Out:
# array(['Bottoms', 'Tops', 'Intimate', 'Jackets', 'Dresses', nan, 'Trend'],
#       dtype=object)

# %%
## Low rating

# %%
dflow_rating=df.loc[(df['rating']<=2)]

dflow_rating

print(dflow_rating['review_text'])
# Out:
# 2        I so wanted this skirt to work, love the desig...
# 13       I really loved this skirt on the model, but it...
# 32       My favorite colors are purple and green, so wh...
# 46       Wanted to like this top but it looks terrible ...
# 47       I just can't get past how different the blouse...
#                                ...
# 23388    This is a rare review for me, i usually love m...
# 23389    I ordered the white and the light blue in size...
# 23397    This may be the ugliest dress with the worst f...
# 23437    I'm not sure what it is with ag. i own at leas...
# 23480    I have to agree with the first reviewer! i rea...
# Name: review_text, Length: 2407, dtype: object

# %%
rc_params={"figure.dpi":150, 'savefig.dpi':300}
sns.set(rc_params)

# %%
df['age'].hist(figsize=(4,4))
plt.show()

# %% [markdown]
# ## Age 40+ involved in more Purchase

# %%
df[:5]
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
grp1 = df.groupby(['division_name', 'class_name'])
 

grp1.aggregate(np.sum)
# Out:
#                                    s.no     age  clothing_id  \
# division_name  class_name
# General        Blouses         23519896   88294      1658066
#                Casual bottoms     23871      53           99
#                Dresses         43380930  156852      4056884
#                Fine gauge       8132594   30828       618051
#                Jackets          4828631   17432       386820
#                Jeans            9276827   34032       808362
#                Knits           37895424  142113      2824970
#                Outerwear        2886485   10613       274764
#                Pants            9672537   36607       883622
#                Shorts           3605668   12911       137723
#                Skirts           7074999   25474       604907
#                Sweaters        10654351   40848       840041
#                Trend            1344275    4283        86111
# General Petite Blouses         13270780   48756       918730
# ...

# %%
sns.relplot(data=df20t030, x="age", y="rating", hue='class_name')
plt.show()

# %%
sns.relplot(data=df30to40, x="age", y="rating", hue='department_name')
plt.show()

# %%
topfive=df['class_name'].value_counts()

top_five=topfive.head(5)

top_five
# Out:
# Dresses     6319
# Knits       4843
# Blouses     3097
# Sweaters    1428
# Pants       1388
# Name: class_name, dtype: int64

# %%
top_five.plot(kind='pie', figsize=(10,10), autopct='%1.1f%%', fontsize=25)
plt.show()

# %%
df['rating'].plot(kind='box', figsize=(18, 8))
plt.show()

# %%
rc_params={"figure.dpi":150, 'savefig.dpi':300}
sns.set(rc_params)

# %%
df['class_name'].hist
plt.show()

# %%
df['department_name'].hist(figsize=(25,25))
plt.show()

# %%
age=df['age'].value_counts()

print(age)

mostbuyer=age.head(10)
mostbuyer
# Out:
# 39    1269
# 35     909
# 36     842
# 34     804
# 38     780
#       ...
# 90       2
# 93       2
# 86       2
# 99       2
# 92       1
# Name: age, Length: 77, dtype: int64
# 39    1269
# 35     909
# 36     842
# 34     804
# 38     780
# 37     766
# 41     741
# 33     725
# 46     713
# 42     651
# Name: age, dtype: int64

# %%
mostbuyer.plot(kind='pie', figsize=(25,25), autopct='%1.1f%%', fontsize=25)
plt.show()

# %%
df.columns
# Out:
# Index(['s.no', 'age', 'division_name', 'department_name', 'class_name',
#        'clothing_id', 'title', 'review_text', 'alike_feedback_count', 'rating',
#        'recommend_index '],
#       dtype='object')

# %%
df.plot(y='rating', kind='hist')
plt.show()

# %%
division=df['division_name'].unique()
division
# Out:
# array(['General', 'General Petite', 'Initmates', nan], dtype=object)

# %%
departmentname=df['department_name'].unique()
departmentname
# Out:
# array(['Bottoms', 'Tops', 'Intimate', 'Jackets', 'Dresses', 'Trend', nan],
#       dtype=object)

# %%
classname=df['class_name'].unique()
classname
# Out:
# array(['Jeans', 'Blouses', 'Skirts', 'Pants', 'Swim', 'Sweaters', 'Knits',
#        'Fine gauge', 'Jackets', 'Dresses', 'Shorts', 'Lounge',
#        'Outerwear', 'Intimates', 'Legwear', 'Sleep', 'Trend', 'Layering',
#        nan, 'Casual bottoms', 'Chemises'], dtype=object)

# %%
Clothingid=df['clothing_id'].unique()
Clothingid
# Out:
# array([1028,  850,  993, ...,   32,  568,  222])

# %%
df1 = df.head(10)
df1.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %%
df1.plot(x='class_name', y='rating', kind='bar', figsize=(12, 5))
plt.show()
